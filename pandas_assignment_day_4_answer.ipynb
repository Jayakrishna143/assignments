# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayakrishna143/assignments/blob/main/pandas_assignment_day_4_answer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### import the Diamond dataset

# %%
import pandas as pd, numpy as np

# %%
df = pd.read_csv('/content/diamonds.csv',index_col=0)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ###### 1. Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe.

# %%
### code here
print(df.info())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53940 entries, 1 to 53940
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.5+ MB
# None
# (53940, 10)

# %% [markdown]
# ##### 2. Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe.

# %%
### code here
df.describe(include='object')
# Out:
#           cut  color clarity
# count   53940  53940   53940
# unique      5      7       8
# top     Ideal      G     SI1
# freq    21551  11292   13065

# %% [markdown]
# ###### 3. Write a Pandas program to remove the second column of the diamonds Dataframe. (don't use original dataset)

# %%
### code here
df1 = df.copy()
df1.drop('carat', axis = 1 ,inplace=True)
df1.head()
# Out:
#        cut color clarity  depth  table  price     x     y     z
# 1    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ###### 4. Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe. (dont use original dataset)

# %%
### code here
df2 = df.copy()
df2.drop([2,4,5], axis = 0 ,inplace=True)
df2.head()
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 3   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53

# %% [markdown]
# ###### 5. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.

# %%
df.cut.sort_values()
# Out:
# 3851          Fair
# 51465         Fair
# 51467         Fair
# 10238         Fair
# 10761         Fair
#            ...
# 7403     Very Good
# 43102    Very Good
# 16894    Very Good
# 16899    Very Good
# 21165    Very Good
# Name: cut, Length: 53940, dtype: object

# %%
### code here
df.sort_values('cut',ascending=True)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 3851    1.01       Fair     F     SI2   64.8   55.0   3477  6.37  6.26  4.10
# 51465   1.20       Fair     G      I1   66.6   57.0   2376  6.57  6.50  4.34
# 51467   0.90       Fair     G     SI2   65.4   57.0   2376  6.01  5.97  3.98
# 10238   1.26       Fair     D     SI2   64.5   59.0   4746  6.75  6.71  4.34
# 10761   1.01       Fair     E     SI1   69.5   55.0   4853  6.00  5.94  4.15
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 7403    0.33  Very Good     G     VS2   62.8   54.0    579  4.40  4.42  2.77
# 43102   0.57  Very Good     E     SI2   58.8   57.3   1384  5.42  5.46  3.21
# 16894   1.00  Very Good     G     VS2   62.2   58.0   6743  6.35  6.39  3.96
# 16899   1.00  Very Good     D     VS2   59.6   60.0   6745  6.52  6.57  3.90
# 21165   1.00  Very Good     E    VVS2   61.7   55.0   9324  6.38  6.42  3.95
#
# [53940 rows x 10 columns]

# %% [markdown]
# ###### 6. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat' Series in ascending and descending order.

# %%
### code here
df.sort_values('carat',ascending=True)
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 15      0.20  Premium     E     SI2   60.2   62.0    345   3.79   3.75  2.27
# 31598   0.20    Ideal     D     VS2   61.5   57.0    367   3.81   3.77  2.33
# 31597   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
# 31596   0.20    Ideal     E     VS2   59.7   55.0    367   3.86   3.84  2.30
# 31595   0.20  Premium     E     VS2   59.7   62.0    367   3.84   3.80  2.28
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 25999   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 26000   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 27131   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27631   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27416   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
#
# [53940 rows x 10 columns]

# %%
df.sort_values('carat',ascending=False)
# Out:
#        carat        cut color clarity  depth  table  price      x      y     z
# 27416   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27631   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27131   4.13       Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 26000   4.01    Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25999   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# ...      ...        ...   ...     ...    ...    ...    ...    ...    ...   ...
# 31594   0.20    Premium     E     VS2   61.1   59.0    367   3.81   3.78  2.32
# 31593   0.20    Premium     E     VS2   59.0   60.0    367   3.81   3.78  2.24
# 31600   0.20      Ideal     E     VS2   62.2   57.0    367   3.76   3.73  2.33
# 31598   0.20      Ideal     D     VS2   61.5   57.0    367   3.81   3.77  2.33
# 31599   0.20  Very Good     E     VS2   63.4   59.0    367   3.74   3.71  2.36
#
# [53940 rows x 10 columns]

# %% [markdown]
# ###### 7. Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

# %%
#### code here
df[df['carat']>=0.3]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 5       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 11      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 14      0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 16      0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 17      0.30      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [52341 rows x 10 columns]

# %% [markdown]
# ###### 8.  Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

# %%
### code here
df[(df['x']>5) & (df['y']>5) & (df['z']>5)]
# Out:
#        carat        cut color clarity  depth  table  price     x      y  \
# 11779   1.83       Fair     J      I1   70.0   58.0   5083  7.34   7.28
# 13003   2.14       Fair     J      I1   69.4   57.0   5405  7.74   7.70
# 13119   2.15       Fair     J      I1   65.5   57.0   5430  8.01   7.95
# 13563   1.96       Fair     F      I1   66.6   60.0   5554  7.59   7.56
# 13758   2.22       Fair     J      I1   66.7   56.0   5607  8.04   8.02
# ...      ...        ...   ...     ...    ...    ...    ...   ...    ...
# 27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90   7.97
# 27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50   8.47
# 48411   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12   5.15
# 49190   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15  31.80
# 49906   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01   5.04
#
#            z         xyz
# 11779   5.12  273.588224
# 13003   5.36  319.445280
# 13119   5.23  333.043785
# 13563   5.04  289.197216
# 13758   5.36  345.617088
# ...      ...         ...
# 27749   5.04  317.333520
# 27750   5.16  371.494200
# 48411  31.80  838.502400
# 49190   5.12  838.502400
# 49906   5.06  127.767024
#
# [1457 rows x 11 columns]

# %% [markdown]
# ###### 9. Write a Pandas program to calculate the mean of each row of diamonds DataFrame.

# %%
### code here
df.mean(axis=0,numeric_only=True)
# Out:
# carat       0.797940
# depth      61.749405
# table      57.457184
# price    3932.799722
# x           5.731157
# y           5.734526
# z           3.538734
# dtype: float64

# %% [markdown]
# ###### 10. Write a Pandas program to calculate the mean of price for each cut  and find maximum top 3 of diamonds DataFrame.

# %%
#### code here
df.groupby('cut')['price'].mean().sort_values(ascending=False).head(3)
# Out:
# cut
# Premium      4584.257704
# Fair         4358.757764
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# ##### 11. Write a Pandas program to calculate count, minimum, maximum price for each cut of diamonds DataFrame.

# %%
### code here
df.groupby('cut')['price'].agg(['count','min','max'])
# Out:
#            count  min    max
# cut
# Fair        1610  337  18574
# Good        4906  327  18788
# Ideal      21551  326  18806
# Premium    13791  326  18823
# Very Good  12082  336  18818

# %% [markdown]
# ###### 12. Write a Pandas program to display and count the unique values in cut series of diamonds DataFrame.

# %%
### code here
df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %% [markdown]
# ######13.  Write a Pandas program to count the number of missing values in each Series of diamonds DataFrame.

# %%
### code here
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# ###### 14. Write a Pandas program to calculate the multiply of x, y and z for each cut of diamonds DataFrame.

# %%
df['xyz'] = df['x'] * df['y'] * df['z']
xyz_by_cut = df.groupby('cut')['xyz'].sum()
xyz_by_cut
# Out:
# cut
# Fair         2.655704e+05
# Good         6.684782e+05
# Ideal        2.486876e+06
# Premium      2.000414e+06
# Very Good    1.582739e+06
# Name: xyz, dtype: float64

# %% [markdown]
# ##### 15. Write a Pandas program to read rows 0 through 2 (inclusive), columns ‘color’ and ‘price’ of diamonds DataFrame.

# %%
## code here
df.loc[0:3,['color','price']]
# Out:
#   color  price
# 1     E    326
# 2     E    326
# 3     E    327

# %% [markdown]
# ###### 16. Write a Pandas program to read rows in positions 0 and 1, columns in positions 0 and 3 of diamonds DataFrame.

# %%
### code here
df.iloc[[0,1],[0,3]]
# Out:
#    carat clarity
# 1   0.23     SI2
# 2   0.21     SI1

# %% [markdown]
# ##### 17. Write a Pandas program to get randomly sample rows from diamonds DataFrame.

# %%
### code here
df.sample(5)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 25525   2.00  Very Good     H     SI2   61.0   57.0  14340  8.02  8.18  4.94
# 22678   1.29      Ideal     F     VS1   62.3   54.4  10727  6.93  7.00  4.34
# 42531   0.40      Ideal     F    VVS1   62.5   57.0   1323  4.75  4.72  2.96
# 35713   0.30    Premium     D     VS2   60.6   58.0    911  4.36  4.32  2.63
# 41910   0.40      Ideal     F      IF   61.8   55.0   1261  4.74  4.80  2.95
#
#               xyz
# 25525  324.081784
# 22678  210.533400
# 42531   66.363200
# 35713   49.536576
# 41910   67.118400

# %% [markdown]
# ###### 18. Write a Pandas program to get sample 75% of the diamonds DataFrame's rows without replacement and store the remaining 25% of the rows in another DataFrame.

# %%
### code here
df1 = df.sample(frac=0.75, random_state=1)
df2 = df.drop(df1.index)
df1,df2
# Out:
# (       carat        cut color clarity  depth  table  price     x     y     z  \
#  2715    0.33      Ideal     H     SI1   61.7   55.0    564  4.43  4.46  2.74
#  14654   1.20      Ideal     I     VS2   62.1   57.0   5914  6.78  6.71  4.19
#  52761   0.62      Ideal     D     VS1   61.0   57.0   2562  5.51  5.54  3.37
#  48659   0.34       Good     H     VS2   63.1   56.0    537  4.41  4.46  2.80
#  14813   1.20      Ideal     E     SI2   62.5   55.0   5964  6.77  6.84  4.25
#  ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
#  27599   2.50    Premium     I     SI2   59.0   60.0  18447  8.76  8.89  5.21
#  39037   0.37      Ideal     G      IF   61.4   55.0   1056  4.63  4.66  2.85
#  21462   1.55  Very Good     E     SI2   59.5   56.0   9557  7.56  7.59  4.51
#  11573   1.02    Premium     F     SI1   59.2   58.0   5038  6.53  6.50  3.86
#  29373   0.31    Premium     E     SI1   59.3   59.0    698  4.48  4.42  2.64
#
#                xyz
#  2715    54.136372
#  14654  190.619022
#  52761  102.870598
#  48659   55.072080
#  14813  196.803900
#  ...           ...
#  27599  405.736044
#  39037   61.491030
#  21462  258.785604
#  11573  163.837700
#  29373   52.276224
#
#  [40455 rows x 11 columns],
#         carat        cut color clarity  depth  table  price     x     y     z  \
#  10      0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
#  15      0.20    Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
#  16      0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
#  19      0.30       Good     J     SI1   63.8   56.0    351  4.23  4.26  2.71
#  21      0.30       Good     I     SI2   63.3   56.0    351  4.26  4.30  2.71
#  ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
#  53927   0.71      Ideal     E     SI1   61.9   56.0   2756  5.71  5.73  3.54
#  53929   0.79    Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
#  53930   0.71      Ideal     G     VS1   61.4   56.0   2756  5.76  5.73  3.53
#  53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#  53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#                xyz
#  10      38.718000
#  15      32.262375
#  16      51.883728
#  19      48.833658
#  21      49.641780
#  ...           ...
#  53927  115.822782
#  53929  132.254784
#  53930  116.506944
#  53939  140.766120
#  53940  124.568444
#
#  [13485 rows x 11 columns])

# %% [markdown]
# ###### 19. Write a Pandas program to read the diamonds DataFrame and detect duplicate color.

# %%
# Find duplicate colors
duplicate_colors = df['color'].duplicated(keep=False)


unique_duplicate_colors = df.loc[duplicate_colors, 'color'].unique()
print("Duplicate Colors:", unique_duplicate_colors)
# Out:
# Duplicate Colors: ['E' 'I' 'J' 'H' 'F' 'G' 'D']

# %%
#### code here
duplicate_color = df[df.duplicated(['color'])]
duplicate_color
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 2       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 6       0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 7       0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 9       0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#               xyz
# 2       34.505856
# 3       38.076885
# 6       38.693952
# 7       38.830870
# 9       36.425214
# ...           ...
# 53936  115.920000
# 53937  118.110175
# 53938  114.449728
# 53939  140.766120
# 53940  124.568444
#
# [53933 rows x 11 columns]

# %% [markdown]
# ###### 20. Write a Pandas program to count the duplicate rows of diamonds DataFrame.

# %%
#### code here
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z  \
# 1006    0.79  Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1007    0.79  Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1008    0.79  Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 1009    0.79  Ideal     G     SI1   62.3   57.0   2898  5.90  5.85  3.66
# 2026    1.52   Good     E      I1   57.3   58.0   3105  7.53  7.42  4.28
# ...      ...    ...   ...     ...    ...    ...    ...   ...   ...   ...
# 47970   0.52  Ideal     D     VS2   61.8   55.0   1919  5.19  5.16  3.20
# 49327   0.51  Ideal     F    VVS2   61.2   56.0   2093  5.17  5.19  3.17
# 49558   0.71   Good     F     SI2   64.1   60.0   2130  0.00  0.00  0.00
# 50080   0.51  Ideal     F    VVS2   61.2   56.0   2203  5.19  5.17  3.17
# 52862   0.50   Fair     E     VS2   79.0   73.0   2579  5.21  5.18  4.09
#
#               xyz
# 1006   126.324900
# 1007   126.324900
# 1008   126.324900
# 1009   126.324900
# 2026   239.134728
# ...           ...
# 47970   85.697280
# 49327   85.058391
# 49558    0.000000
# 50080   85.058391
# 52862  110.380102
#
# [146 rows x 11 columns]
