# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayakrishna143/assignments/blob/main/pandas_assignment_day_1_iris__answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### step 1. load the iris.csv dataset.

# %%
! pip install pyjanitor
# Out:
# Collecting pyjanitor
#   Downloading pyjanitor-0.31.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: natsort in /usr/local/lib/python3.11/dist-packages (from pyjanitor) (8.4.0)
# Collecting pandas_flavor (from pyjanitor)
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: multipledispatch in /usr/local/lib/python3.11/dist-packages (from pyjanitor) (1.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyjanitor) (1.14.1)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.11/dist-packages (from pandas_flavor->pyjanitor) (2.2.2)
# Requirement already satisfied: xarray in /usr/local/lib/python3.11/dist-packages (from pandas_flavor->pyjanitor) (2025.1.2)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy->pyjanitor) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.23->pandas_flavor->pyjanitor) (2025.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from xarray->pandas_flavor->pyjanitor) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_flavor->pyjanitor) (1.17.0)
# Downloading pyjanitor-0.31.0-py3-none-any.whl (215 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.4/215.4 kB 4.1 MB/s eta 0:00:00
# Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Installing collected packages: pandas_flavor, pyjanitor
# Successfully installed pandas_flavor-0.6.0 pyjanitor-0.31.0

# %%
import pandas as pd,numpy as np
from janitor import clean_names

# %% [markdown]
# ##### 1. Write a Pandas program to get the data types of the given csv data (iris.csv ) fields

# %%
### code here
df = pd.read_csv('/content/Iris.csv')
df = clean_names(df)
df
# Out:
#       id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ##### 2. Write a Pandas program to find the sum, mean, max, min value of 'SepalLengthCm' column of dataframe

# %%
### code here
df['sepallengthcm'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepallengthcm, dtype: float64

# %% [markdown]
# ##### 3. Write a Pandas program to import iris data and skipping first twenty rows into a Pandas dataframe.

# %%
### code here
df1 = pd.read_csv('/content/Iris.csv',skiprows=20,header = 0)
df1
# Out:
#       20  5.1  3.8  1.5  0.3     Iris-setosa
# 0     21  5.4  3.4  1.7  0.2     Iris-setosa
# 1     22  5.1  3.7  1.5  0.4     Iris-setosa
# 2     23  4.6  3.6  1.0  0.2     Iris-setosa
# 3     24  5.1  3.3  1.7  0.5     Iris-setosa
# 4     25  4.8  3.4  1.9  0.2     Iris-setosa
# ..   ...  ...  ...  ...  ...             ...
# 125  146  6.7  3.0  5.2  2.3  Iris-virginica
# 126  147  6.3  2.5  5.0  1.9  Iris-virginica
# 127  148  6.5  3.0  5.2  2.0  Iris-virginica
# 128  149  6.2  3.4  5.4  2.3  Iris-virginica
# 129  150  5.9  3.0  5.1  1.8  Iris-virginica
#
# [130 rows x 6 columns]

# %% [markdown]
# ##### 4. Write a Pandas program to display the last ten rows.

# %%
### code here
df.tail(10)
# Out:
#       id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# ##### 5. Write a Pandas program to create a subtotal of "PetalLengthCm" against Species from the dataframe.

# %%
### code here
df.groupby('Species')['PetalLengthCm'].sum()
# Out:
# Species
# Iris-setosa         73.2
# Iris-versicolor    213.0
# Iris-virginica     277.6
# Name: PetalLengthCm, dtype: float64

# %% [markdown]
# ###### 6. Write a Pandas program to find details where "PetalLengthCm" > 2.

# %%
### code here
df[df.petallengthcm > 2]
# Out:
#       id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#              species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ..               ...
# 145   Iris-virginica
# 146   Iris-virginica
# 147   Iris-virginica
# 148   Iris-virginica
# 149   Iris-virginica
#
# [100 rows x 6 columns]

# %% [markdown]
# ###### 7. Write a Pandas program find all records that include two specific Species.

# %%
### code here
df[df.species.isin(['Iris-setosa','Iris-versicolor'])]
# Out:
#      id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0     1            5.1           3.5            1.4           0.2
# 1     2            4.9           3.0            1.4           0.2
# 2     3            4.7           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# 96  Iris-versicolor
# 97  Iris-versicolor
# 98  Iris-versicolor
# 99  Iris-versicolor
#
# [100 rows x 6 columns]

# %% [markdown]
# ###### 8.  Write a Pandas program to sort the records by the SepalLengthCm column.

# %%
### code here
df.sort_values('sepallengthcm')
# Out:
#       id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 13    14            4.3           3.0            1.1           0.1
# 8      9            4.4           2.9            1.4           0.2
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 135  136            7.7           3.0            6.1           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             species
# 13      Iris-setosa
# 8       Iris-setosa
# 42      Iris-setosa
# 38      Iris-setosa
# 41      Iris-setosa
# ..              ...
# 122  Iris-virginica
# 117  Iris-virginica
# 118  Iris-virginica
# 135  Iris-virginica
# 131  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ##### 9. Write a Pandas program to insert a column in the sixth position of dataframe and fill it with NaN values.

# %%
### code here

df.insert(6,'NanCol',np.nan,False)
df
# Out:
#       id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             species  NanCol
# 0       Iris-setosa     NaN
# 1       Iris-setosa     NaN
# 2       Iris-setosa     NaN
# 3       Iris-setosa     NaN
# 4       Iris-setosa     NaN
# ..              ...     ...
# 145  Iris-virginica     NaN
# 146  Iris-virginica     NaN
# 147  Iris-virginica     NaN
# 148  Iris-virginica     NaN
# 149  Iris-virginica     NaN
#
# [150 rows x 7 columns]

# %% [markdown]
# ##### 10. Write a Pandas program to add summation to a row of the dataframe.

# %%
n_col = df.select_dtypes(include=np.number).columns
df['summation'] = df[n_col].sum(axis=1)
df
# Out:
#       id  sepallengthcm  sepalwidthcm  petallengthcm  petalwidthcm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             species  NanCol  summation
# 0       Iris-setosa     NaN       11.2
# 1       Iris-setosa     NaN       11.5
# 2       Iris-setosa     NaN       12.4
# 3       Iris-setosa     NaN       13.4
# 4       Iris-setosa     NaN       15.2
# ..              ...     ...        ...
# 145  Iris-virginica     NaN      163.2
# 146  Iris-virginica     NaN      162.7
# 147  Iris-virginica     NaN      164.7
# 148  Iris-virginica     NaN      166.3
# 149  Iris-virginica     NaN      165.8
#
# [150 rows x 8 columns]
